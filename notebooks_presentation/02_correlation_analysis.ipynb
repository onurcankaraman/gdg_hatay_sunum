# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

data_path = '/Users/onurcan/Documents/GDG_HATAY/Dataset.xlsx'
df = pd.read_excel(data_path)
df_clean = df.dropna()
numeric_df = df_clean.select_dtypes(include=[np.number])
corr = numeric_df.corr()
display(corr.round(3))
# Out:
#                AşınmaOranı  Kesme Gücü  İlerleme Hızı    RPM
# AşınmaOranı          1.000      -0.579         -0.575 -0.411
# Kesme Gücü          -0.579       1.000          0.917  0.836
# İlerleme Hızı       -0.575       0.917          1.000  0.901
# RPM                 -0.411       0.836          0.901  1.000

# %%
plt.figure(figsize=(8,6))
sns.heatmap(corr, annot=True, cmap='coolwarm', fmt='.2f', center=0, square=True, linewidths=0.5, cbar_kws={'label':'Korelasyon'})
plt.title('Korelasyon Isı Haritası')
plt.tight_layout()
plt.show()

# %%
corr_pairs = corr.unstack()
corr_pairs = corr_pairs[corr_pairs != 1.0]
corr_pairs = corr_pairs.sort_values(ascending=False)
print('En yüksek pozitif korelasyonlar:')
print(corr_pairs.head(10).round(3))
print('En yüksek negatif korelasyonlar:')
print(corr_pairs.tail(10).round(3))
# Out:
# En yüksek pozitif korelasyonlar:
# Kesme Gücü     İlerleme Hızı    0.917
# İlerleme Hızı  Kesme Gücü       0.917
#                RPM              0.901
# RPM            İlerleme Hızı    0.901
# Kesme Gücü     RPM              0.836
# RPM            Kesme Gücü       0.836
# AşınmaOranı    RPM             -0.411
# RPM            AşınmaOranı     -0.411
# AşınmaOranı    İlerleme Hızı   -0.575
# İlerleme Hızı  AşınmaOranı     -0.575
# dtype: float64
# En yüksek negatif korelasyonlar:
# İlerleme Hızı  RPM              0.901
# RPM            İlerleme Hızı    0.901
# Kesme Gücü     RPM              0.836
# RPM            Kesme Gücü       0.836
# AşınmaOranı    RPM             -0.411
# RPM            AşınmaOranı     -0.411
# AşınmaOranı    İlerleme Hızı   -0.575
# İlerleme Hızı  AşınmaOranı     -0.575
# AşınmaOranı    Kesme Gücü      -0.579
# Kesme Gücü     AşınmaOranı     -0.579
# dtype: float64
